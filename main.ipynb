# %%
import pandas as pd
# from thefuzz import fuzz, process
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from concurrent.futures import ProcessPoolExecutor

# %% [markdown]
# # AIM: COMPARE and INTEGRATE THE PRODUCTIONS OF 2 DATASET
# ## Get the overview of the products / market

# %%
# Reading the first CSV file and printing its head
df1 = pd.read_csv('./marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv')

# Reading the second CSV file and printing its head
df2 = pd.read_csv('./marketing_sample_for_walmart_com-product_details__20200101_20200331__30k_data.csv')

# %%
print(df1['Brand Name'].value_counts())
print(df2['Brand'].value_counts())
# Out:
# Series([], Name: count, dtype: int64)
# Brand
# Unique Bargains          338
# Generic                  310
# Anself                   230
# Nike                     130
# Under Armour             106
#                         ...
# Sevylor                    1
# Amber Sports               1
# J is for Jeep              1
# Johnson &amp; Johnson      1
# BRITTANIES THYME           1
# Name: count, Length: 11382, dtype: int64

# %%
# Display options for dataframe
pd.set_option('display.max_rows', 10)  # maximum number of rows to display
pd.set_option('display.max_columns', 10)  # maximum number of columns to display
pd.set_option('display.width', 200)  # width of the display in characters
pd.set_option('display.colheader_justify', 'center')  # center the column headers

print(df1.columns)
print(df2.columns)
# Out:
# Index(['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category', 'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity', 'Model Number', 'About Product', 'Product Specification',
#        'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image', 'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details', 'Dimensions', 'Color', 'Ingredients', 'Direction To Use',
#        'Is Amazon Seller', 'Size Quantity Variant', 'Product Description'],
#       dtype='object')
# Index(['Uniq Id', 'Crawl Timestamp', 'Product Url', 'Product Name', 'Description', 'List Price', 'Sale Price', 'Brand', 'Item Number', 'Gtin', 'Package Size', 'Category', 'Postal Code', 'Available'], dtype='object')

# %%
print(df2[['Product Name', 'Category']].head())
print(df2[['Brand', 'List Price', 'Sale Price', 'Gtin', 'Description']].head())
# Out:
#                      Product Name                                         Category
# 0  Allegiance Economy Dual-scale Digital Thermometer  Health | Medicine Cabinet | Thermometers | Dig...
# 1  Kenneth Cole Reaction Eau De Parfum Spray For ...  Premium Beauty | Premium Fragrance | Premium P...
# 2  Kid Tough Fitness Inflatable Free-Standing Pun...  Sports & Outdoors | Outdoor Sports | Hunting |...
# 3                                    THE FIRST YEARS                      Baby | Diapering | Baby Wipes
# 4  4 Pack - MD USA Seamless Toe-Wave-In Mesh Diab...            Health | Diabetes Care | Diabetic Socks
#        Brand        List Price  Sale Price      Gtin                        Description
# 0  Cardinal Health     11.11       11.11    707389636164   We aim to show you accurate product informati...
# 1     Kenneth Cole     23.99       23.99    191565696101   We aim to show you accurate product informati...
# 2         BONK FIT     30.76       30.76    855523007070   We aim to show you accurate product informati...
# 3  The First Years      6.99        6.99     71463046263   We aim to show you accurate product informati...
# 4           MD USA     28.27       28.27    191897514500  We aim to show you accurate product informatio...

# %%
print(df1[['Brand Name', 'List Price', 'Selling Price', 'Upc Ean Code', 'Product Description']].value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 10):  # more options can be specified also
    print(df1.count())
    print()
    print(df2.count())
# Out:
# Uniq Id                  10002
# Product Name             10002
# Brand Name                   0
# Asin                         0
# Category                  9172
# Upc Ean Code                34
# List Price                   0
# Selling Price             9895
# Quantity                     0
# Model Number              8230
# About Product             9729
# Product Specification     8370
# Technical Details         9212
# Shipping Weight           8864
# Product Dimensions         479
# Image                    10002
# Variants                  2478
# Sku                          0
# Product Url              10002
# Stock                        0
# Product Details              0
# Dimensions                   0
# Color                        0
# Ingredients                  0
# Direction To Use             0
# Is Amazon Seller         10002
# Size Quantity Variant        0
# Product Description          0
# dtype: int64
#
# Uniq Id            30000
# Crawl Timestamp    30000
# Product Url        30000
# Product Name       30000
# Description        30000
# List Price         30000
# Sale Price         30000
# Brand              29481
# Item Number         8554
# Gtin               30000
# Package Size           0
# Category           29976
# Postal Code            0
# Available          30000
# dtype: int64

# %%
def filter_features(df, threshold):
    threshold = threshold * len(df)

# Filter features with more than 80% non-NaN values
    selected_features = df.count()[df.count() > threshold].index.tolist()

    # Print the feature names
    print("Features with more than 80% values:")
    print("\n".join(selected_features))
    return selected_features

# %%
filter_features(df1, 0.8)
filter_features(df2, 0.8)
# Out:
# Features with more than 80% values:
# Uniq Id
# Product Name
# Category
# Selling Price
# Model Number
# About Product
# Product Specification
# Technical Details
# Shipping Weight
# Image
# Product Url
# Is Amazon Seller
# Features with more than 80% values:
# Uniq Id
# Crawl Timestamp
# Product Url
# Product Name
# Description
# List Price
# Sale Price
# Brand
# Gtin
# Category
# Available
# ['Uniq Id',
#  'Crawl Timestamp',
#  'Product Url',
#  'Product Name',
#  'Description',
#  'List Price',
#  'Sale Price',
#  'Brand',
#  'Gtin',
#  'Category',
#  'Available']

# %%
column_mapping = {
    # Mapping for `df1`
    'Uniq Id': 'Unique ID',
    'Product Name': 'Product Name',
    'Category': 'Category',
    'Selling Price': 'Sale Price',
    'Model Number': 'Model Number',
    'About Product': 'Description',
    'Product Specification': 'Specifications',
    'Technical Details': 'Technical Details',
    'Shipping Weight': 'Shipping Weight',
    'Image': 'Image',
    'Product Url': 'Product URL',
    'Is Amazon Seller': 'Is Amazon Seller',
    
    # Mapping for `df2`
    'Crawl Timestamp': 'Crawl Timestamp',
    'Description': 'Description',
    'List Price': 'List Price',
    'Sale Price': 'Sale Price',
    'Brand': 'Brand Name',
    'Gtin': 'UPC/EAN Code',
    'Available': 'Availability'
}

# %%
# Rename columns for df1
df1_cleaned = df1.rename(columns=column_mapping)

# Rename columns for df2
df2_cleaned = df2.rename(columns=column_mapping)

# %%
import re

def clean_price_column(price_column):
    def clean_price_range(price_str):
        # Regular expression to match price range (e.g., '74.99 - 249.99')
        match = re.match(r"(\d+(\.\d+)?)\s*-\s*(\d+(\.\d+)?)", price_str.strip())
        
        if match:
            # Extracting the lower and upper price bounds
            lower_price = float(match.group(1))
            upper_price = float(match.group(3))
            return lower_price, upper_price
        else:
            return None, None  # Return None if no valid range is found

    def clean_price(value):
        # Check for price range
        if isinstance(value, str) and ' - ' in value:
            lower_price, upper_price = clean_price_range(value)
            return lower_price, upper_price if lower_price is not None and upper_price is not None else None
        else:
            # Remove common currency symbols and commas
            value = str(value).replace('$', '').replace('€', '').replace('₹', '').replace('£', '').replace(',', '')
            try:
                return float(value)  # Convert to float directly
            except ValueError:
                return None  # In case the value cannot be converted to a float
    
    return price_column.apply(clean_price)

# %%
df1_cleaned['Sale Price'] = clean_price_column(df1_cleaned['Sale Price'])
df2_cleaned['Sale Price'] = clean_price_column(df2_cleaned['Sale Price'])

# %%
filter_features(df1_cleaned, 0.8)
# Out:
# Features with more than 80% values:
# Unique ID
# Product Name
# Category
# Sale Price
# Model Number
# Description
# Specifications
# Technical Details
# Shipping Weight
# Image
# Product URL
# Is Amazon Seller
# ['Unique ID',
#  'Product Name',
#  'Category',
#  'Sale Price',
#  'Model Number',
#  'Description',
#  'Specifications',
#  'Technical Details',
#  'Shipping Weight',
#  'Image',
#  'Product URL',
#  'Is Amazon Seller']

# %%
common_features = set(df1_cleaned.columns) & set(df2_cleaned.columns) & set(filter_features(df1_cleaned, 0.8)) & set(filter_features(df2_cleaned, 0.8))
print('Common features:', common_features)
# Out:
# Features with more than 80% values:
# Unique ID
# Product Name
# Category
# Sale Price
# Model Number
# Description
# Specifications
# Technical Details
# Shipping Weight
# Image
# Product URL
# Is Amazon Seller
# Features with more than 80% values:
# Unique ID
# Crawl Timestamp
# Product URL
# Product Name
# Description
# List Price
# Sale Price
# Brand Name
# UPC/EAN Code
# Category
# Availability
# Common features: {'Product Name', 'Unique ID', 'Product URL', 'Sale Price', 'Category', 'Description'}

# %%
usable_features = common_features - {'Unique ID', 'Product URL', 'Sale Price'}

usable_features = sorted(usable_features, reverse=True)

# %%
def preprocess_and_concat(df, common_features):
    df[common_features] = df[common_features].fillna('')
    df['concat'] = df[common_features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
preprocess_and_concat(df1_cleaned, list(usable_features))
preprocess_and_concat(df2_cleaned, list(usable_features))
df1_cleaned.columns
# Out:
# Index(['Unique ID', 'Product Name', 'Brand Name', 'Asin', 'Category',
#        'Upc Ean Code', 'List Price', 'Sale Price', 'Quantity', 'Model Number',
#        'Description', 'Specifications', 'Technical Details', 'Shipping Weight',
#        'Product Dimensions', 'Image', 'Variants', 'Sku', 'Product URL',
#        'Stock', 'Product Details', 'Dimensions', 'Color', 'Ingredients',
#        'Direction To Use', 'Is Amazon Seller', 'Size Quantity Variant',
#        'Product Description', 'concat'],
#       dtype='object')

# %%
# Tokenize category to a dict with index
def tokenize_category(df):
    return df['Category'].apply(lambda x: x.lower().split(' | '))

# %%
token2 =tokenize_category(df2_cleaned)
dict2 = dict()
for idx, token in enumerate(token2):
    for cate in token:
        if cate not in dict2:
            dict2[cate] = set()  # Initialize the list if the category is not in the dictionary
        dict2[cate].add(idx)

# %%
len(dict2)
# Out:
# 4678

# %%
df1_cleaned['concat']
# Out:
# 0        DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
# 1        Electronic Snap Circuits Mini Kits Classpack, ...
# 2        3Doodler Create Flexy 3D Printing Filament Ref...
# 3        Guillow Airplane Design Studio with Travel Cas...
# 4        Woodstock- Collage 500 pc Puzzle Make sure thi...
#                                ...
# 9997     Remedia Publications REM536B Money Activity Bo...
# 9998     Trends International NFL La Chargers HG - Mobi...
# 9999     NewPath Learning 10 Piece Science Owls and Owl...
# 10000    Disney Princess Do It Yourself Braid Set  Toys...
# 10001    Hasegawa Ladders Lucano Step Ladder, Orange Ma...
# Name: concat, Length: 10002, dtype: object

# %%
df1_cleaned['Category'].value_counts()
# Out:
# Category
#                                                                                                                                            830
# Toys & Games | Games & Accessories | Board Games                                                                                           284
# Toys & Games | Puzzles | Jigsaw Puzzles                                                                                                    274
# Toys & Games | Stuffed Animals & Plush Toys | Stuffed Animals & Teddy Bears                                                                252
# Toys & Games | Toy Figures & Playsets | Action Figures                                                                                     235
#                                                                                                                                           ...
# Toys & Games | Hobbies | Remote & App Controlled Vehicles & Parts | Remote & App Controlled Vehicle Parts | Servos & Parts | Servo Arms      1
# Sports & Outdoors | Sports & Fitness | Team Sports | Ice Hockey | Pucks                                                                      1
# Toys & Games | Kids' Furniture, Décor & Storage | Outdoor Furniture | Picnic Tables                                                          1
# Sports & Outdoors | Sports & Fitness | Leisure Sports & Game Room | Outdoor Games & Activities | Bocce | Bocce Sets                          1
# Clothing, Shoes & Jewelry | Novelty & More | Clothing | Novelty | Men | Shirts                                                               1
# Name: count, Length: 939, dtype: int64

# %%
token1 =tokenize_category(df1_cleaned)
dict1 = dict()
for idx, token in enumerate(token1):
    for cate in token:
        if cate not in dict1:
            dict1[cate] = set()  # Initialize the list if the category is not in the dictionary
        dict1[cate].add(idx)

# %%
fuzzy_matching_list = {}
# Perform fuzzy matching with 2 token dict 1, 2
for token1 in dict1.keys():
    for token2 in dict2.keys():
        score = fuzz.token_set_ratio(token1, token2)
        
        fuzzy_matching_list[(token1, token2)] = score

# %%
fuzzy_matching_list

# %%
matching_product_list = []
# Matching Category to the best category in df2
for idx, row in df1_cleaned.iterrows():
    # Tokenize category for df2
    token1 = row['Category'].lower().split(' | ')
    if token1 == ['']:
        continue
    print(idx, token1)
    # Compare with dict1 using fuzzy matching
    common_list = None
    for _, cate in enumerate(token1):
        for dict_cate in dict2.keys():
            score = fuzzy_matching_list[(cate, dict_cate)]
            if score > 80:
                # print(f"{cate} -> {dict_cate} with score {score}")
                if common_list is None:
                    common_list = set(dict2[dict_cate])
                else:
                    common_list = common_list | set(dict2[dict_cate])
                # print("common_list:", common_list)
    if common_list is None:
        continue
    df2_strings = df2_cleaned.loc[list(common_list), 'concat'].tolist()
    top_match = process.extract(row['concat'], df2_strings, scorer=fuzz.token_set_ratio, score_cutoff=50)
    if top_match:
        for index, x in enumerate(top_match):
            top_match[index] = (x[0], x[1], list(common_list)[x[2]])
            # print(f"{row['Product Name']} -> {df2_cleaned['Product Name'][match_index]} with score {score}")
        # print(f"{row['Product Name']} -> {df1_cleaned['Product Name'][match_index]} with score {score}")
        matching_product_list.append((idx, top_match))
        print("===============================================")
        print(f"Matched {len(matching_product_list)} products")
        print("===============================================")
# Out:
# 0 ['sports & outdoors', 'outdoor recreation', 'skates, skateboards & scooters', 'skateboarding', 'standard skateboards & longboards', 'longboards']
# ===============================================
# Matched 1 products
# ===============================================
# 1 ['toys & games', 'learning & education', 'science kits & toys']
# 2 ['toys & games', 'arts & crafts', 'craft kits']
# ===============================================
# Matched 2 products
# ===============================================
# 3 ['toys & games', 'hobbies', 'models & model kits', 'model kits', 'airplane & jet kits']
# 4 ['toys & games', 'puzzles', 'jigsaw puzzles']
# 6 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'girls', 'costumes']
# 7 ['toys & games', 'arts & crafts', 'drawing & painting supplies', 'crayons']
# 8 ['home & kitchen', 'home décor', 'window treatments', 'window stickers & films', 'window films']
# 10 ['toys & games', 'baby & toddler toys']
# ===============================================
# Matched 3 products
# ===============================================
# 11 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts', 'statues']
# 12 ['baby products', 'nursery', 'décor', 'window treatments', 'valances']
# ===============================================
# Matched 4 products
# ===============================================
# 13 ['toys & games', 'building toys', 'building sets']
# ===============================================
# Matched 5 products
# ===============================================
# 14 ['toys & games', 'arts & crafts', 'craft kits']
# 15 ['toys & games', 'baby & toddler toys', 'musical toys']
# ===============================================
# Matched 6 products
# ===============================================
# 16 ['toys & games', 'learning & education', 'flash cards']
# ===============================================
# Matched 7 products
# ===============================================
# 17 ['home & kitchen', 'furniture', "kids' furniture", 'tables & chairs', 'tables']
# 18 ['toys & games', 'novelty & gag toys', 'money banks']
# ===============================================
# Matched 8 products
# ===============================================
# 19 ['toys & games', 'baby & toddler toys', 'musical toys']
# 20 ['toys & games', 'sports & outdoor play', 'slumber bags']
# 21 ['toys & games', 'hobbies', 'hobby building tools & hardware', 'rc linkages']
# 22 ['toys & games', 'building toys', 'building sets']
# ===============================================
# Matched 9 products
# ===============================================
# 23 ['toys & games', 'party supplies', 'party tableware', 'plates']
# 24 ['toys & games', 'baby & toddler toys', 'teaching clocks']
# ===============================================
# Matched 10 products
# ===============================================
# 25 ['toys & games', 'tricycles, scooters & wagons', 'balance bikes']
# ===============================================
# Matched 11 products
# ===============================================
# 26 ['toys & games', "kids' electronics"]
# 27 ['home & kitchen', 'home décor', "kids' room décor"]
# 28 ['baby products', 'nursery', 'décor', 'wall décor', 'growth charts']
# ===============================================
# Matched 12 products
# ===============================================
# 29 ['toys & games', 'puzzles', 'jigsaw puzzles']
# 30 ['sports & outdoors', 'sports & fitness', 'team sports']
# ===============================================
# Matched 13 products
# ===============================================
# 31 ['toys & games', 'dress up & pretend play', 'costumes']
# ===============================================
# Matched 14 products
# ===============================================
# 32 ['home & kitchen', 'bedding', "kids' bedding", 'comforters & sets', 'comforter sets']
# ===============================================
# Matched 15 products
# ===============================================
# 33 ['toys & games', 'toy figures & playsets', 'action figures']
# 34 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'boys', 'costumes']
# ===============================================
# Matched 16 products
# ===============================================
# 35 ['toys & games', 'play vehicles']
# 36 ['toys & games', 'novelty & gag toys']
# 37 ['toys & games', 'party supplies']
# ===============================================
# Matched 17 products
# ===============================================
# 38 ['toys & games', 'party supplies', 'banners']
# ===============================================
# Matched 18 products
# ===============================================
# 39 ['toys & games', 'dolls & accessories', 'doll accessories']
# ===============================================
# Matched 19 products
# ===============================================
# 41 ['toys & games', 'arts & crafts', 'craft kits']
# 42 ['toys & games', 'games & accessories']
# ===============================================
# Matched 20 products
# ===============================================
# 43 ['toys & games', 'hobbies', 'trains & accessories', 'train cars', 'freight cars', 'gondolas']
# 44 ['home & kitchen', 'bedding', "kids' bedding", 'blankets & throws', 'throws']
# ===============================================
# Matched 21 products
# ===============================================
# 45 ['pet supplies', 'dogs', 'training & behavior aids', 'agility equipment', 'tunnels']
# 46 ['toys & games', 'dolls & accessories', 'dolls']
# ===============================================
# Matched 22 products
# ===============================================
# 47 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts']
# 48 ['toys & games', 'learning & education']
# 49 ['toys & games', "kids' electronics", 'electronic learning toys']
# ===============================================
# Matched 23 products
# ===============================================
# 51 ['clothing, shoes & jewelry', 'novelty & more', 'clothing', 'novelty', 'men', 'shirts', 't-shirts']
# 52 ['toys & games', 'hobbies', 'hobby building tools & hardware', 'paints']
# 53 ['toys & games', 'arts & crafts']
# ===============================================
# Matched 24 products
# ===============================================
# 54 ['toys & games', 'games & accessories', 'card games']
# ===============================================
# Matched 25 products
# ===============================================
# 55 ['toys & games', 'dress up & pretend play', 'pretend play', 'kitchen toys']
# 57 ['toys & games', 'dolls & accessories', 'dolls']
# ===============================================
# Matched 26 products
# ===============================================
# 58 ['toys & games', "kids' electronics", 'electronic learning toys']
# 59 ['toys & games', 'games & accessories']
# ===============================================
# Matched 27 products
# ===============================================
# 60 ['clothing, shoes & jewelry', 'men', 'accessories', 'wallets, card cases & money organizers', 'wallets']
# 61 ['toys & games', 'toy figures & playsets', 'action figures']
# 62 ['toys & games', 'baby & toddler toys']
# 63 ['toys & games', 'baby & toddler toys', 'sorting & stacking toys']
# ===============================================
# Matched 28 products
# ===============================================
# 64 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts', 'statues']
# 65 ['clothing, shoes & jewelry', 'costumes & accessories', 'women', 'wigs']
# 66 ['toys & games', 'toy figures & playsets', 'action figures']
# 68 ['toys & games', 'toy figures & playsets', 'action figures']
# 69 ['toys & games', 'stuffed animals & plush toys', 'stuffed animals & teddy bears']
# ===============================================
# Matched 29 products
# ===============================================
# 70 ['toys & games', 'dolls & accessories', 'dolls']
# ===============================================
# Matched 30 products
# ===============================================
# 71 ['toys & games', 'dolls & accessories', 'playsets']
# 72 ['toys & games', 'stuffed animals & plush toys', 'stuffed animals & teddy bears']
# ===============================================
# Matched 31 products
# ===============================================
# 73 ['toys & games', 'novelty & gag toys', 'miniatures']
# ===============================================
# Matched 32 products
# ===============================================
# 74 ['toys & games', 'stuffed animals & plush toys', 'plush puppets']
# 75 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts', 'wheels & tires', 'tires']
# 76 ['home & kitchen', 'home décor', "kids' room décor", 'wall décor']
# 78 ['toys & games', 'stuffed animals & plush toys', 'plush figures']
# 79 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts', 'power plant & driveline systems', 'axles']
# ===============================================
# Matched 33 products
# ===============================================
# 80 ['sports & outdoors', 'sports & fitness', 'team sports', 'volleyball', 'volleyballs', 'outdoor volleyballs']
# ===============================================
# Matched 34 products
# ===============================================
# 81 ['toys & games', 'toy figures & playsets', 'playsets & vehicles', 'playsets']
# 82 ['toys & games', 'arts & crafts', 'clay & dough']
# 83 ['toys & games', 'games & accessories', 'board games']
# ===============================================
# Matched 35 products
# ===============================================
# 84 ['toys & games', 'stuffed animals & plush toys', 'plush figures']
# ===============================================
# Matched 36 products
# ===============================================
# 85 ['toys & games', 'games & accessories', 'game accessories', 'standard game dice']
# ===============================================
# Matched 37 products
# ===============================================
# 86 ['toys & games', "kids' electronics"]
# 87 ['toys & games', 'dolls & accessories', 'dolls']
# 88 ['sports & outdoors', 'fan shop', 'toys & game room', 'games']
# ===============================================
# Matched 38 products
# ===============================================
# 90 ['toys & games', 'dress up & pretend play', 'pretend play', 'kitchen toys', 'play food']
# 91 ['toys & games', 'party supplies', 'banners']
# 92 ['toys & games', 'baby & toddler toys']
# ===============================================
# Matched 39 products
# ===============================================
# 93 ['toys & games', 'hobbies', 'trains & accessories', 'train cars']
# 95 ['toys & games', 'games & accessories', 'card games', 'standard playing card decks']
# ===============================================
# Matched 40 products
# ===============================================
# 96 ['toys & games', 'stuffed animals & plush toys']
# 97 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts']
# 98 ['toys & games', "kids' electronics"]
# 99 ['toys & games', 'games & accessories', 'card games', 'standard playing card decks']
# 100 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicles', 'quadcopters & multirotors']
# 101 ['arts, crafts & sewing', 'crafting', 'paper & paper crafts', 'paper craft tools']
# 102 ['toys & games', 'building toys']
# 103 ['toys & games', 'party supplies']
# 104 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'girls', 'costumes']
# ===============================================
# Matched 41 products
# ===============================================
# 105 ['toys & games', 'learning & education', 'science kits & toys']
# 106 ['toys & games', 'dolls & accessories', 'dolls']
# 107 ['toys & games', 'sports & outdoor play', 'play sets & playground equipment']
# ===============================================
# Matched 42 products
# ===============================================
# 109 ['toys & games', 'stuffed animals & plush toys', 'plush pillows']
# 110 ['home & kitchen', 'home décor', "kids' room décor", 'window treatments', 'curtain panels']
# ===============================================
# Matched 43 products
# ===============================================
# 111 ['toys & games', 'arts & crafts', 'clay & dough']
# ===============================================
# Matched 44 products
# ===============================================
# 113 ['toys & games', 'games & accessories', 'board games']
# ===============================================
# Matched 45 products
# ===============================================
# 114 ['toys & games', 'sports & outdoor play', 'play sets & playground equipment', 'teeter totters']
# ===============================================
# Matched 46 products
# ===============================================
# 115 ['sports & outdoors', 'fan shop', 'electronics', 'computer accessories']
# ===============================================
# Matched 47 products
# ===============================================
# 116 ['sports & outdoors', 'sports & fitness', 'leisure sports & game room', 'outdoor games & activities', 'balls', 'playground balls']
# 117 ['toys & games', 'toy figures & playsets', 'action figures']
# 118 ['home & kitchen', 'furniture', "kids' furniture", 'chairs & seats', 'armchairs']
# 119 ['toys & games', 'games & accessories']
# ===============================================
# Matched 48 products
# ===============================================
# 120 ['electronics', 'camera & photo', 'binoculars & scopes', 'binoculars']
# 121 ['toys & games', 'arts & crafts']
# 122 ['toys & games', 'novelty & gag toys']
# 123 ['toys & games', 'dolls & accessories', 'dolls']
# 124 ['toys & games', 'toy figures & playsets']
# ===============================================
# Matched 49 products
# ===============================================
# 125 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts', 'servos & parts', 'servos']
# 126 ['toys & games', 'arts & crafts', 'clay & dough']
# 127 ['toys & games', 'building toys']
# 128 ['toys & games', 'learning & education', 'flash cards']
# ===============================================
# Matched 50 products
# ===============================================
# 129 ['toys & games', 'hobbies', 'remote & app controlled vehicles & parts', 'remote & app controlled vehicle parts', 'battery chargers']
# 130 ['toys & games', 'arts & crafts', 'craft kits']
# 131 ['toys & games', 'dolls & accessories', 'dolls']
# 132 ['toys & games', 'puzzles', 'jigsaw puzzles']
# 133 ['arts, crafts & sewing', 'beading & jewelry making', 'beading supplies', 'fuse & perler beads']
# 134 ['toys & games', 'novelty & gag toys']
# ===============================================
# Matched 51 products
# ===============================================
# 135 ['toys & games', 'toy figures & playsets', 'action figures']
# 136 ['video games', 'playstation 4', 'games']
# 137 ['toys & games', 'puzzles', 'brain teasers']
# 138 ['toys & games', 'games & accessories', 'card games', 'standard playing card decks']
# ===============================================
# Matched 52 products
# ===============================================
# 139 ['toys & games', 'dolls & accessories', 'dolls']
# ===============================================
# Matched 53 products
# ===============================================
# 140 ['toys & games', 'dolls & accessories', 'doll accessories']
# 141 ['baby products', 'baby care', 'pacifiers, teethers & teething relief', 'teethers']
# ===============================================
# Matched 54 products
# ===============================================
# 142 ['toys & games', 'stuffed animals & plush toys', 'stuffed animals & teddy bears']
# ===============================================
# Matched 55 products
# ===============================================
# 143 ['toys & games', 'building toys', 'building sets']
# 144 ['toys & games', 'hobbies', 'trains & accessories', 'train cars', 'freight cars']
# 145 ['toys & games', 'games & accessories', 'card games']
# ===============================================
# Matched 56 products
# ===============================================
# 147 ['patio, lawn & garden', 'outdoor décor', 'backyard birding & wildlife', 'butterflies']
# 148 ['toys & games', 'toy figures & playsets', 'action figures']
# 149 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts', 'statues']
# 150 ['clothing, shoes & jewelry', 'costumes & accessories', 'women', 'costumes & cosplay apparel', 'costumes']
# 151 ['toys & games', 'hobbies', 'hobby building tools & hardware', 'paints']
# 152 ['toys & games', 'games & accessories', 'board games']
# 153 ['tools & home improvement', 'power & hand tools', 'power tool parts & accessories', 'power rotary tool parts & accessories', 'attachments']
# 154 ['toys & games', 'party supplies']
# ===============================================
# Matched 57 products
# ===============================================
# 155 ['toys & games', 'games & accessories']
# ===============================================
# Matched 58 products
# ===============================================
# 156 ['toys & games', 'party supplies', 'party packs']
# ===============================================
# Matched 59 products
# ===============================================
# 157 ['toys & games', 'games & accessories']
# ===============================================
# Matched 60 products
# ===============================================
# 158 ['toys & games', 'learning & education', 'flash cards']
# 159 ['toys & games', 'games & accessories', 'card games', 'standard playing card decks']
# ===============================================
# Matched 61 products
# ===============================================
# 160 ['toys & games', 'play vehicles', 'die-cast vehicles']
# ===============================================
# Matched 62 products
# ===============================================
# 161 ['toys & games', 'building toys', 'building sets']
# 162 ['toys & games', 'arts & crafts', 'craft kits', 'jewelry']
# ===============================================
# Matched 63 products
# ===============================================
# 163 ['toys & games', 'party supplies', 'party tableware', 'napkins']
# 164 ['clothing, shoes & jewelry', 'costumes & accessories', 'men', 'accessories', 'headwear']
# ===============================================
# Matched 64 products
# ===============================================
# 165 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts', 'statues']
# 166 ['toys & games', 'dress up & pretend play', 'costumes']
# 167 ['toys & games', 'hobbies', 'slot cars, race tracks & accessories', 'slot cars']
# ===============================================
# Matched 65 products
# ===============================================
# 168 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'girls', 'costumes']
# 169 ['toys & games', 'novelty & gag toys']
# 170 ['clothing, shoes & jewelry', 'costumes & accessories', 'men', 'accessories']
# 171 ['sports & outdoors', 'sports & fitness', 'leisure sports & game room', 'arcade & table games', 'air hockey']
# ===============================================
# Matched 66 products
# ===============================================
# 172 ['toys & games', 'baby & toddler toys', 'sorting & stacking toys']
# ===============================================
# Matched 67 products
# ===============================================
# 173 ['clothing, shoes & jewelry', 'costumes & accessories', 'women', 'costumes & cosplay apparel', 'costumes']
# 174 ['toys & games', 'baby & toddler toys', 'activity play centers']
# ===============================================
# Matched 68 products
# ===============================================
# 175 ['toys & games', 'learning & education', 'science kits & toys']
# ===============================================
# Matched 69 products
# ===============================================
# 177 ['toys & games', 'arts & crafts', 'craft kits']
# ===============================================
# Matched 70 products
# ===============================================
# 178 ['toys & games', 'toy figures & playsets', 'playsets & vehicles', 'playsets']
# ===============================================
# Matched 71 products
# ===============================================
# 179 ['toys & games', 'learning & education', 'science kits & toys']
# ===============================================
# Matched 72 products
# ===============================================
# 180 ['toys & games', 'play vehicles', 'vehicle playsets']
# ===============================================
# Matched 73 products
# ===============================================
# 181 ['baby products', 'nursery', 'décor', 'wall décor', 'stickers']
# ===============================================
# Matched 74 products
# ===============================================
# 183 ['toys & games', 'toy figures & playsets', 'action figures']
# 184 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'girls', 'costumes']
# 185 ['toys & games', 'arts & crafts', 'stickers']
# ===============================================
# Matched 75 products
# ===============================================
# 186 ['arts, crafts & sewing', 'painting, drawing & art supplies', 'drawing', 'drawing media', 'pencils']
# 187 ['toys & games', 'toy figures & playsets', 'action figures']
# 188 ['toys & games', 'hobbies', 'trains & accessories', 'accessories', 'tracks']
# 189 ['clothing, shoes & jewelry', 'costumes & accessories', 'women', 'costumes & cosplay apparel', 'costumes']
# 190 ['toys & games', 'baby & toddler toys', 'rattles & plush rings']
# ===============================================
# Matched 76 products
# ===============================================
# 193 ['toys & games', 'baby & toddler toys', 'activity play centers']
# ===============================================
# Matched 77 products
# ===============================================
# 194 ['clothing, shoes & jewelry', 'costumes & accessories', 'women', 'costumes & cosplay apparel', 'costumes']
# 195 ['toys & games', 'building toys', 'building sets']
# 196 ['toys & games', 'stuffed animals & plush toys']
# 198 ['toys & games', 'puzzles']
# ===============================================
# Matched 78 products
# ===============================================
# 200 ['toys & games', 'toy figures & playsets', 'playsets & vehicles', 'playsets']
# ===============================================
# Matched 79 products
# ===============================================
# 201 ['tools & home improvement', 'lighting & ceiling fans', 'wall lights', 'night lights']
# 203 ['toys & games', 'stuffed animals & plush toys']
# ===============================================
# Matched 80 products
# ===============================================
# 204 ['clothing, shoes & jewelry', 'costumes & accessories', 'kids & baby', 'girls', 'costumes']
# ===============================================
# Matched 81 products
# ===============================================
# 205 ['toys & games', 'puzzles', 'jigsaw puzzles']
# 207 ['toys & games', 'dress up & pretend play', 'costumes']
# ===============================================
# Matched 82 products
# ===============================================
# 208 ['clothing, shoes & jewelry', 'costumes & accessories', 'men', 'masks']
# 209 ['toys & games', "kids' electronics", 'electronic learning toys']
# ===============================================
# Matched 83 products
# ===============================================
# 210 ['toys & games', 'play vehicles', 'die-cast vehicles']
# 211 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts', 'bobbleheads']
# 212 ['toys & games', 'party supplies', 'party favors']
# ===============================================
# Matched 84 products
# ===============================================
# 213 ['toys & games', 'puzzles', 'brain teasers']
# 214 ['toys & games', 'baby & toddler toys', 'sorting & stacking toys']
# 215 ['clothing, shoes & jewelry', 'costumes & accessories', 'men', 'costumes & cosplay apparel', 'costumes']
# 216 ['toys & games', 'dress up & pretend play', 'pretend play', 'paper & magnetic dolls', 'magnetic dress-up dolls']
# 217 ['toys & games', 'arts & crafts', 'craft kits', 'jewelry']
# 218 ['office products', 'office & school supplies']
# 219 ['toys & games', 'stuffed animals & plush toys', 'stuffed animals & teddy bears']
# ===============================================
# Matched 85 products
# ===============================================
# 220 ['toys & games', 'hobbies', 'models & model kits', 'model kits', 'figure kits']
# ===============================================
# Matched 86 products
# ===============================================
# 221 ['toys & games', 'collectible toys', 'statues, bobbleheads & busts']
# 223 ['toys & games', 'dress up & pretend play', 'costumes']
# ===============================================
# Matched 87 products
# ===============================================
# 225 ['sports & outdoors', 'outdoor recreation', 'cycling', "kids' bikes & accessories", "kids' bikes"]

# %%
matching_product_list
# Out:
# [(1807,
#   [('The Elixir Eatra Large Baby Play Mat Crawling Non-Toxic Playmat, Child Kids Non-Slip Floor Mat, Reversible Waterproof Hyeienic Padded for Toddlers, 82 x 55 x 0.47 inch (made in Korea)  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |The Elixir Eco Green Extra Large Non-Toxic Reversible Baby Infant Plat Mat Foam Floor Gym Rug The Elixir Eco Green Play Mat provides a safe and comfy place for babies and children to play. The cushioned mat protects against hard falls when kids do what they do best. Approx. 20 Lbs Mat is sturdy so they work well on hardwood floors or carpets. Kids of all ages love the vibrant colors, and in no time theyre identifying numbers and images from the pictures on the mats. FEATURES Babies and children can play on the soft floor surface from birth to school safely. It is waterproof and easy to clean: just wipe with a soft damp cloth for food and drink. It is also perfect for reducing noise and impact, and a great insulator for all floor surfaces. Baby Kids Safe Materials Waterproof and easy to clean Cute educational alphabet letters/images Gender-free design for boys and girls Protects little knees & hands from hard flooring BPA & Toxin Free means no nasty chemicals or smells EXCEEDS CPSC & CPSIA STANDARDS ... 100% toxin free, odorless & anti-slip for safe sure-footed play, Made in South Korea DOUBLE SIDED DESIGN ... Our infant plat mat is designed sturdy to protect your prince/princess and with a purpose in mind. our activity mat has a fun educational alphabet, animals, or objects WATERPROOF AND CREASE RESISTANT ... guaranteed to stay looking new, easily wipe away drool & spit-up SAFETY, SAFETY, AND SAFETY ... Phthalate Free, BPA Free, Lead-Free, Latex Free, Formaldehyde Free, EVA Free LARGE COMFY PLAY AREA … 82 x 55 inch oversize mat for a large play, perfect for tummy-time to crawling to first steps and beyond! |EXCEEDS CPSC & CPSIA STANDARDS ... 100% toxin free, odorless & anti-slip for safe sure-footed play, Made in South Korea|DOUBLE SIDED DESIGN ... Our infant plat mat is designed sturdy to protect your prince/princess and with a purpose in mind. our activity mat has a fun educational alphabet, animals, or objects|WATERPROOF AND CREASE RESISTANT ... guaranteed to stay looking new, easily wipe away drool & spit-up|SAFETY, SAFETY, AND SAFETY ... Phthalate Free, BPA Free, Lead-Free, Latex Free, Formaldehyde Free, EVA Free|LARGE COMFY PLAY AREA … 82 x 55 inch oversize mat for a large play, perfect for tummy-time to crawling to first steps and beyond! Baby | Baby Activities & Gear | Gyms & Playmats',
#     51.8664047151277,
#     23659),
#    ('Neat Solutions Disney Winnie the Pooh Meal and Play Mat  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Perfect under high chairs or under the dining table chairs when using a booster seat Disposable for easy clean up Protect floors and carpets. Very durable. Use again and again! Great for home and away. 36" x 48" generously sized. BPA-Free, phthalate-Free. Baby | Baby Activities & Gear | Gyms & Playmats',
#     51.78147268408551,
#     10805)]),
#  (2322,
#   [('KABOER Reusable Kids Children Toddler Foldable Travel Toilet Potty Seat Pad Cushion Mat  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |Reusable Kids Children Toddler Foldable Travel Toilet Potty Seat Pad Cushion Mat Welcome To KABOER! Home | Kitchen & Dining | Kitchen & Table Linens | Table Linens | Chair Pads & Chair Cushions',
#     61.53846153846154,
#     27351),
#    ('(#32) Hotel Quality Silver Grommet Top, Faux Silk 1 Panel Gold Solid Thermal Foam Lined Blackout Heavy Thick Window Curtain Drapes Grommets 95" Length  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |You Will Receive 1 Thermal Panel Each Panel SIZE: 37"W x 95"Provides Great Privacy and also Helps insulate against heat and cold Energy Efficient/Light Filtering/Noise ReducingThese Room darkening Blackout Curtains Has White Foam Backing to Block about up to 80% of Light compared to ordinary curtainsDECORATIVE ROD SIZE: 2" OR LESS FITSMASHINE WASH COLD TUMBLE DRY LOW Home | Decor | Curtains & Window Treatments | Curtains | Kitchen Curtains',
#     57.89473684210526,
#     16672),
#    ('Mr. Scrappy Custom Colored Sink Flange, White  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Mr. Scrappy Custom Colored Sink Flange, White: Made of solid brass Will enhance your kitchen appearance to coordinate with your faucets and other fixtures Fits all Waste Maid, Titan, Commodore or GE brands and some Waste King models 1-year warranty Garbage disposal flange color: white Includes stopper Model# CSFS-WH-93 Enhance the look of your sink basin and kitchen with the Mr. Scrappy Custom Colored Garbage Disposal Sink Flange. Made of solid brass, it screws into place for quick and easy installation. It is also versatile and fits a wide range of disposals, such as all Waste Maid, Commodore, Titan or GE brands and some Waste King models. The white color complements almost any kitchen decor. A matching white stopper is included with this Waste King sink flange for when you want to retain water in the sink or prevent objects from entering the disposal unit.|Made of solid brass|Will enhance your kitchen appearance to coordinate with your faucets and other fixtures|Fits all Waste Maid, Titan, Commodore or GE brands and some Waste King models|1-year warranty|Garbage disposal flange color: white|Includes stopper|Model# CSFS-WH-93 Home | Kitchen & Dining | Kitchen Storage & Organization | Sink Accessories',
#     57.89473684210526,
#     18910),
#    ('((#86) Hotel Quality Grommet Top, Jacquard 1 Panel Charcoal Solid Thermal Foam Lined Blackout Heavy Thick Window Curtain Drapes Bronze Grommets 95" Length  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |You Will Receive 1 Thermal Panel Each Panel SIZE: 37"W x 95"Provides Great Privacy and also Helps insulate against heat and cold Energy Efficient/Light Filtering/Noise ReducingThese Room darkening Blackout Curtains Has White Foam Backing to Block about up to 80% of Light compared to ordinary curtainsDECORATIVE ROD SIZE: 2" OR LESS FITSMASHINE WASH COLD TUMBLE DRY LOW Home | Decor | Curtains & Window Treatments | Curtains | Kitchen Curtains',
#     57.89473684210526,
#     16909),
#    ('Surya SEV2301-1616 18 in. Seville Area Rug, Dark Blue, Medium Gray & White We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Surya is a leading provider of home accessories for a variety of lifestyles and budgets. Products include rugs, pillows, throws, wall decor, accent furniture, lighting, decorative accents and bedding, which are sold through a broad spectrum. While Surya creates thousands of its own designs, we also work with renowned and emerging talent. Signature style does not manifest overnight. It takes years of creative development, collaboration and refinement to arrive at the themes, motifs and palettes that eventually become hallmarks. The unique fusion between the Surya brand and our pioneering design partners allows us to deliver a comprehensive collection in serious style. Features Machine Woven Medium Pile Specifications Color: Dark Blue, Medium Gray, White Collection: Seville Material: 100% Polypropylene Country of Origin: Egypt Size: 18 in. Weight: 1 lbs - SKU: SYRA108753|Machine Woven|Medium Pile|Color: Dark Blue, Medium Gray, White|Collection: Seville|Material: 100% Polypropylene|Country of Origin: Egypt|Size: 18 in.|Weight: 1 lbs Home | Decor | Rugs | Kitchen Rugs',
#     57.89473684210526,
#     8953)]),
#  (2707,
#   [('4x6 Classic Detailed Black Picture Frame We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Decorative picture frame Black velvet backing Vertical or horizontal tabletop display or can be hung on a wall with installed hangers Wipe clean with dry cloth, glass included Holds 4 inch by 6 inch photo, vertical or horizontal High quality black composite picture frame. Beautifully finished picture frame that will be a great decorative addition to any room. Comes with a two way easel for vertical or horizontal table top display, and hangers for vertical or horizontal wall mounting. High quality black velvet backing. Picture frame comes with glass to protect your photo, and is individually boxed.|Decorative picture frame|Black velvet backing|Vertical or horizontal tabletop display or can be hung on a wall with installed hangers|Wipe clean with dry cloth, glass included|Holds 4 inch by 6 inch photo, vertical or horizontal Home | Decor | Picture Frames',
#     50.69393718042367,
#     20715),
#    ('3 Sprouts Canvas Storage Bin - Laundry and Toy Basket for Baby and Kids We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Storage bins are 17.5" height and 17" diameter Bin collapses for easy storage when not in use Coated on the inside so its easy to wipe clean It is made up of 100% cotton canvas Handles on the side of the bin make it easy to hold and transport wherever you need it. Help your kids clean up their act with our cute animal storage bins. Well sized for storing toys, books or laundry. A great space saver, our bin folds easily away when not in use. The 3 Sprouts storage bin is a perfect gift for babies, toddlers and kids.|Storage bins are 17.5" height and 17" diameter|Bin collapses for easy storage when not in use|Coated on the inside so its easy to wipe clean|It is made up of 100% cotton canvas|Handles on the side of the bin make it easy to hold and transport wherever you need it. Home | Storage & Organization | Storage Baskets & Bins | Shop All Storage Baskets & Bins',
#     50.39941902687001,
#     28751)]),
#  (4367,
#   [('Boardwalk Gray Professional Ostrich Feather Duster  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |Keep your space clean with help from this Boardwalk Gray Professional Ostrich Feather Duster. The unique articulation of the bristles help to attract and trap dirt/dust particles on counter surfaces, shelves, television screens and more. This Boardwalk feather household duster comes with a gorgeous 7" stained, contoured wood handle and 6" bristles for extended reach that will help you clean hard-to-reach places. Boardwalk Gray Professional Ostrich Feather Duster: Professional quality gray feathers Cleaning feather duster attracts and holds dust Stained, contoured wood handle with hang-up hole Bristle material: ostrich feather Bristle length: 6" Handle length: 7" Handle material: wood; bristle color: gray Model number: BWK13FD |Professional quality gray feathers|Cleaning feather duster attracts and holds dust|Stained, contoured wood handle with hang-up hole|Bristle material: ostrich feather|Bristle length: 6"|Handle length: 7"|Handle material: wood; bristle color: gray|Model number: BWK13FD Industrial & Scientific | Janitorial & Sanitation Supplies | Cleaning Tools | Commercial Dusting Supplies',
#     51.37844611528822,
#     1449)]),
#  (7132,
#   [('Oil Ring in Brass - 2 3/4" Diameter. We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |Fits any ordinary light bulb. Fill brass channel with scented oil. The scent is dispersed by the warmth of the bulb. 2 3/4" Home | Decor | Lighting & Light Fixtures | Lighting Accessories',
#     50.13333333333333,
#     2330)]),
#  (8523,
#   [('The Kids Room by Stupell This is My Happy Place Copper Typography Oversized Stretched Canvas Wall Art, 24 x 1.5 x 30  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Dimensions: 24 x 1.5 x 30 Inches Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang Our vibrant canvas art makes decorating for children of all ages a whole lot easier. Design By Daphne Polselli Our stretched canvas is created with only the highest standards. We print with high quality inks and canvas, and then hand cut and stretch it over a 1.5 inch thick wooden frame. The art comes ready to hang with no installation required. Not to mention, at this size, it is sure to be the focal point of any room!|Dimensions: 24 x 1.5 x 30 Inches|Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang|Our vibrant canvas art makes decorating for children of all ages a whole lot easier.|Design By Daphne Polselli Home | Kids Rooms | Kids Room Decor | Kids Wall Decor',
#     64.04692082111437,
#     1077),
#    ('The Kids Room by Stupell Elephant Family Pink Balloon Linen Look Stretched Canvas Wall Art We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Dimensions: 17 x 1.5 x 17 Inches Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang Our vibrant canvas art makes decorating for children of all ages a whole lot easier. Design By Studio Q Our stretched canvas is created with only the highest standards. We print with high quality inks and canvas, and then hand cut and stretch it over a 1.5 inch thick wooden frame. The art comes ready to hang with no installation required.|Dimensions: 17 x 1.5 x 17 Inches|Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang|Our vibrant canvas art makes decorating for children of all ages a whole lot easier.|Design By Studio Q Home | Kids rooms | Kids room decor | Kids wall decor',
#     61.01281269066504,
#     4265),
#    ('First Birthday Girl Double White 5 x 7-Inch Photo Frame Baby Wall Art  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |Includes: 1 white photo frame, 1 art print, Frame has two 5x7-inch openings. Total frame size is 10x13-inch., Wall mount only, frame is for hanging. Frame does not sit on table., Frame is made of wood, Looking for creative nursery and baby room decor ideas? Create a cute nursery or kid?s bedroom with nursery wall art, children?s wall hangings and inspirational kid?s art prints. These ready to use hanging frame décor prints are ideal for living rooms, office desks, childrens bedroom, playroom, or bonus room. Our high quality white wood frame provide inspiration to both kids and adults alike. Capture each moment and display the photo along with a lovely quote. Makes a lovely baby shower gift or arrival gift. The easy to use frame is durable and sturdy for hanging. Eexclusively designed by Andaz Press. Made in the USA. All images and designs are copyrighted by Andaz Press. Home | Decor | Picture Frames',
#     52.856380138814735,
#     8813),
#    ('Royal Designs True Bell Lamp Shade - Black - 6.5 x 12 x 10.5 We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |Exterior Fabric: Hand Tailored Silk-Type Shantung (except Linen, Mouton, Burlap & Faux Rawhide fabrics), Frame: Heavy grade rust resistant metal frame, Height is measured by slant height from top to bottom of the lampshades front face, Please measure your existing shade--a replacement harp may be needed for a proper fit or additional adjustment if changing height of shade The True Bell Lamp Shade is a part of Royal Designs, Inc. Regal Basic Shade Collection. Traditional True Bell with the options of Flame clip, Round Clip and Uno. This classic lampshade will never go out of style with its high quality fabric and frame. Royal Designs has been in the lampshade business since 1993 with their multiple shade lines that exemplify handcrafted quality and value. Home | Decor | Lighting & Light Fixtures | Lamps | Lamp Shades',
#     51.83982683982684,
#     18458),
#    ('Mainstays Motion Sensor Trash Can, 13.2 Gallon, Stainless Steel We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Sensor-activated lid opens automatically and allows for hands-free operation Garbage can fits a standard sized 13 gallon trash bag Sturdy construction for a long life Dimensions: 11.34" W x 16.38" L x 26.42" H Fingerprint-resistant stainless steel finish adds a stylish flare anywhere it is placed Perfect for the office, breakroom, kitchen, and more Non-skid base Features a ring liner to hold the trash bag in place Wipe clean with a damp cloth Model # MS-50-22 The Mainstays Motion Sensor Trash Can makes disposing of your household refuse easy. With a sleek design, this waste can features a sensor-operated lid that anticipates when you will need to get rid of trash quickly and opens to make trash disposal hands-free. Perfect for an office, kitchen, and more, the garbage can adds a stylish flare anywhere it is placed. Constructed with a fingerprint-resistant stainless steel finish, the Mainstays Motion Sensor Trash Can has a non-skid base for a lifetime of reliable use. These cans hold 13 gallon trash can liners with a ring liner to keep the bag securely at the top of the can and are easily cleaned with a wet or damp cloth.|Sensor-activated lid opens automatically and allows for hands-free operation|Garbage can fits a standard sized 13 gallon trash bag|Sturdy construction for a long life|Dimensions: 11.34" W x 16.38" L x 26.42" H|Fingerprint-resistant stainless steel finish adds a stylish flare anywhere it is placed|Perfect for the office, breakroom, kitchen, and more|Non-skid base|Features a ring liner to hold the trash bag in place|Wipe clean with a damp cloth|Model # MS-50-22 Home | Kitchen & Dining | Kitchen Storage & Organization | Trash Cans | Shop All Trash Cans',
#     51.267865375749196,
#     20796)]),
#  (9712,
#   [('Educational Insights The Sneaky, Snacky Squirrel Game  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer |? Make sure this fits by entering your model number.? NO READING REQUIRED! Your forest pals are hungry and need your help. Help them find their acorns in this fun and addictive toddler board game designed to teach young children about colors. Easy to understand and play?no reading required. Easy set up and clean up; box doubles as storage.? BEST-SELLING PRESCHOOL GAME 5 YEARS RUNNING! Reinforces color learning and helps develop matching skills, strategic thinking, turn-taking, hand-eye coordination, and fine motor skills.? HOW TO PLAY: Spin the spinner and pick up the matching acorn with your Squirrel Squeezer, placing it in your log. The first to collect 5 acorns wins!? INCLUDES colorful tree-shaped game board, Squirrel Squeezer, 20 colored acorns, 1 game spinner, 4 logs, and instruction guide.? AWARD WINNING! Winner of Parents Choice Award, Dr. Toy Best Picks, Good Housekeeping Best Toy, Canadian Toy Testing Council, and NAPPA Games Honors awards.? Squirrel themed game? Game board doubles as packaging? Develops matching, sorting, strategic thinking, hand-eye coordination, fine motor skills and pre-handwriting skills Educational Insights The Sneaky, Snacky Squirrel Game Baby | Baby & Toddler Toys | Baby Learning Toys',
#     54.406130268199234,
#     2940),
#    ('Baby Activity Gym Game Center Turtle Play Mat Infant Hanging Toys Toddler Balls Pit Grow Development Station  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | The gym is an ideal choice for use in homes and day cares due to its quality construction. It helps to enhance motor skills, encourages independent play and captures the attention of infants and toddlers. Sit & Play The sit and play format combines arch activity play with ball pit format. In this format babies can continue to build on fine and gross motor skills as well as acquiring new skills like early object and color recognition, and basic problem solving. Great Value, Lots Of Play This gym is packed with play. It comes with five activity toys that offer unique textures and sound, which can be positioned in many places on the gym and ball pit. It also comes with 40 balls and a large play mat thats both comfortable and visually stimulating. What is really unique is the pop-up mesh side, which can be used to surround baby during lay and play use, or to create the ball pit play environment. Lay & Play The lay and play format creates a sensory playground for small babies. Babies are surrounded by visually stimulating toys that encourage visual development like tracking. The hanging activities toys also encourage early fine and gross motors skills as babies begin to reach, bat, grab, and kick at interesting toys. These motions make toys sway, jingle, and rattle, which create more visual and auditory stimulation and an entertaining reason to do it again. The large surrounding mat help give baby a comfortable and defined space to play. Ball Pit Play The ball pit format creates a fun zone for busy toddlers. At this stage little ones can move around within the pit and have fun putting the balls and activity toys through the strategically placed holes around the mesh pit. It is a great space and opportunity for parents to continue to build their child?s descriptive language and objection recognition through play. Designed With Parents In Mind This action-packed, unique gym was designed with many developmental features for baby, but also some very important parent-friendly features as well. Of course, parents will be thrilled with how much enjoyment their baby gets from the gym, but they?ll also love the convenient, built in storage for all 40 of the balls. Description: Material: PP Cotton Color: Multi Colors Age requirements: over 0 month Toy Style: Fish, star and so on. Diameter: 68cm/26.77(appr.) Height: 50cm/19.69"(appr.) The gym is an ideal choice for use in homes and day cares due to its quality construction. It helps to enhance motor skills, encourages independent play and captures the attention of infants and toddlers. Sit & Play The sit and play format combines arch activity play with ball pit format. In this format babies can continue to build on fine and gross motor skills as well as acquiring new skills like early object and color recognition, and basic problem solving. 0 Months+ 4 linkable sea pals 40 colorful balls store inside turtles head Toy Style: Fish, star and so on. An activity gym and ball pit in one |The gym is an ideal choice for use in homes and day cares due to its quality construction. It helps to enhance motor skills, encourages independent play and captures the attention of infants and toddlers. |Sit & Play|The sit and play format combines arch activity play with ball pit format. In this format babies can continue to build on fine and gross motor skills as well as acquiring new skills like early object and color recognition, and basic problem solving.|Great Value, Lots Of Play|This gym is packed with play. It comes with five activity toys that offer unique textures and sound, which can be positioned in many places on the gym and ball pit. It also comes with 40 balls and a large play mat thats both comfortable and visually stimulating ...
#     50.98039215686274,
#     772),
#    ('Dexbaby Big Mouth Leak-Proof Dura Bib w/ Catch-All Pocket - Large | 6 months + (4 Pack) We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Get it right the first time! This is the best bib you will ever need. The patented Catch-All pocket on the Dex Baby - Big Mouth Dura Bibs help prevent messes. Unsnap and wipe off for quick and easy clean up wherever you are. With 100 percent woven cotton backing and brushed tricot fabric, these snap bibs provide comfortable protection for your babys clothes during meal time. This cute and durable bib from Dexbaby makes for a great baby shower gift. Mom and her little one will appreciate you forever. Enjoy your feeding time with ease of mind, watch your child develop eating skills and independence at mealtime without the big mess. Includes 4 Patterns: \xa0Cow, Duck, Lion, Turtle PATENTED "CATCH-ALL" POCKET ? will greatly enhance your feeding experience. Its well-designed pocket will contain spills and reduce loads of laundry! This must have bib will be your favorite little helper to let your child learn how to eat by themselves instead of worrying about the mess. WATERPROOF & LEAK-PROOF SOLUTION - 100% woven cotton backing and brushed tricot fabric will provide you the best bib you will ever need, with extra comfortable protection for your babys clothes during meal time you will be able to feed your baby with ease and peace of mind. ADORABLE DESIGN & LIGHTWEIGHT ? Your little one will love this adorable and engaging design! It unsnaps and wipes off easily for quick clean up anywhere. DISHWASHER SAFE ? Throw your messy bib in your dishwasher or rinse it off worry free. Easy to clean! Designed to withstand wash after wash with its silk screened ink image protected. Stain and odor resistant - BPA, PVC, Vinyl, Phthalate and Lead free. LIFETIME GUARANTEE - DEX Products will replace or repair, free of charge, any product that is defective or malfunctioning during the effective life of the product. |Includes 4 Patterns: \xa0Cow, Duck, Lion, Turtle |PATENTED "CATCH-ALL" POCKET ? will greatly enhance your feeding experience. Its well-designed pocket will contain spills and reduce loads of laundry! This must have bib will be your favorite little helper to let your child learn how to eat by themselves instead of worrying about the mess. |WATERPROOF & LEAK-PROOF SOLUTION - 100% woven cotton backing and brushed tricot fabric will provide you the best bib you will ever need, with extra comfortable protection for your babys clothes during meal time you will be able to feed your baby with ease and peace of mind. |ADORABLE DESIGN & LIGHTWEIGHT ? Your little one will love this adorable and engaging design! It unsnaps and wipes off easily for quick clean up anywhere. |DISHWASHER SAFE ? Throw your messy bib in your dishwasher or rinse it off worry free. Easy to clean! Designed to withstand wash after wash with its silk screened ink image protected. Stain and odor resistant - BPA, PVC, Vinyl, Phthalate and Lead free. |LIFETIME GUARANTEE - DEX Products will replace or repair, free of charge, any product that is defective or malfunctioning during the effective life of the product. Baby | Feeding | Bibs and Burp Cloths',
#     50.98039215686274,
#     26725)]),
#  (9909,
#   [('The Kids Room by Stupell This is My Happy Place Copper Typography Oversized Stretched Canvas Wall Art, 24 x 1.5 x 30  We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Dimensions: 24 x 1.5 x 30 Inches Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang Our vibrant canvas art makes decorating for children of all ages a whole lot easier. Design By Daphne Polselli Our stretched canvas is created with only the highest standards. We print with high quality inks and canvas, and then hand cut and stretch it over a 1.5 inch thick wooden frame. The art comes ready to hang with no installation required. Not to mention, at this size, it is sure to be the focal point of any room!|Dimensions: 24 x 1.5 x 30 Inches|Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang|Our vibrant canvas art makes decorating for children of all ages a whole lot easier.|Design By Daphne Polselli Home | Kids Rooms | Kids Room Decor | Kids Wall Decor',
#     80.68181818181819,
#     1077),
#    ('The Kids Room by Stupell Elephant Family Pink Balloon Linen Look Stretched Canvas Wall Art We aim to show you accurate product information. Manufacturers, suppliers and others provide what you see here, and we have not verified it. See our disclaimer | Dimensions: 17 x 1.5 x 17 Inches Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang Our vibrant canvas art makes decorating for children of all ages a whole lot easier. Design By Studio Q Our stretched canvas is created with only the highest standards. We print with high quality inks and canvas, and then hand cut and stretch it over a 1.5 inch thick wooden frame. The art comes ready to hang with no installation required.|Dimensions: 17 x 1.5 x 17 Inches|Our Canvas is Hand Stretched on a 1.5 Inch Thick Wood Frame - Ready to Hang|Our vibrant canvas art makes decorating for children of all ages a whole lot easier.|Design By Studio Q Home | Kids rooms | Kids room decor | Kids wall decor',
#     80.0,
#     4265)])]

# %%
len(matching_product_list)
# Out:
# 8

# %%
for pair in matching_product_list:
    # print(pair)
    df1_idx = pair[0]
    df2_topmatch = pair[1]
    for _, score, df2_idx in df2_topmatch:
        print(score)
        print(df1_cleaned["Product Name"][df1_idx])
        print(df2_cleaned["Product Name"][df2_idx])

        print(df1_cleaned["Sale Price"][df1_idx])
        print(df2_cleaned["Sale Price"][df2_idx])
# Out:
# 51.8664047151277
# Play with Pieces, Reversible Play Mat, Moroccan Rug Plus Polka Dot
# The Elixir Eatra Large Baby Play Mat Crawling Non-Toxic Playmat, Child Kids Non-Slip Floor Mat, Reversible Waterproof Hyeienic Padded for Toddlers, 82 x 55 x 0.47 inch (made in Korea)
# 149.0
# 159.0
# 51.78147268408551
# Play with Pieces, Reversible Play Mat, Moroccan Rug Plus Polka Dot
# Neat Solutions Disney Winnie the Pooh Meal and Play Mat
# 149.0
# 12.95
# 61.53846153846154
# Angeles Toddler White Cot Sheet
# KABOER Reusable Kids Children Toddler Foldable Travel Toilet Potty Seat Pad Cushion Mat
# 15.16
# 14.76
# 57.89473684210526
# Angeles Toddler White Cot Sheet
# (#32) Hotel Quality Silver Grommet Top, Faux Silk 1 Panel Gold Solid Thermal Foam Lined Blackout Heavy Thick Window Curtain Drapes Grommets 95" Length
# 15.16
# 7.0
# 57.89473684210526
# Angeles Toddler White Cot Sheet
# Mr. Scrappy Custom Colored Sink Flange, White
# 15.16
# 37.91
# 57.89473684210526
# Angeles Toddler White Cot Sheet
# ((#86) Hotel Quality Grommet Top, Jacquard 1 Panel Charcoal Solid Thermal Foam Lined Blackout Heavy Thick Window Curtain Drapes Bronze Grommets 95" Length
# 15.16
# 7.0
# 57.89473684210526
# Angeles Toddler White Cot Sheet
# Surya SEV2301-1616 18 in. Seville Area Rug, Dark Blue, Medium Gray & White
# 15.16
# 45.0
# 50.69393718042367
# DCI Pop Quiz Clock, Black and White, Metal, 11-1/2" Diameter, Mathematics Teacher Gift, Wall Clock for Classroom, Home, Office
# 4x6 Classic Detailed Black Picture Frame
# 22.29
# 9.56
# 50.39941902687001
# DCI Pop Quiz Clock, Black and White, Metal, 11-1/2" Diameter, Mathematics Teacher Gift, Wall Clock for Classroom, Home, Office
# 3 Sprouts Canvas Storage Bin - Laundry and Toy Basket for Baby and Kids
# 22.29
# 24.99
# 51.37844611528822
# 3B Scientific A13 Sam the Super Skeleton w/ pelvic roller stand - 3B Smart Anatomy
# Boardwalk Gray Professional Ostrich Feather Duster
# 629.0
# 11.11
# 50.13333333333333
# Beware Large Styrofoam Halloween Sign
# Oil Ring in Brass - 2 3/4" Diameter.
# 19.21
# 2.77
# 64.04692082111437
# The Kids Room By Stupell Dinosaurs Typography Chart Oversized Stretched Canvas Wall Art
# The Kids Room by Stupell This is My Happy Place Copper Typography Oversized Stretched Canvas Wall Art, 24 x 1.5 x 30
# 53.78
# 50.26
# 61.01281269066504
# The Kids Room By Stupell Dinosaurs Typography Chart Oversized Stretched Canvas Wall Art
# The Kids Room by Stupell Elephant Family Pink Balloon Linen Look Stretched Canvas Wall Art
# 53.78
# 31.49
# 52.856380138814735
# The Kids Room By Stupell Dinosaurs Typography Chart Oversized Stretched Canvas Wall Art
# First Birthday Girl Double White 5 x 7-Inch Photo Frame Baby Wall Art
# 53.78
# 22.99
# 51.83982683982684
# The Kids Room By Stupell Dinosaurs Typography Chart Oversized Stretched Canvas Wall Art
# Royal Designs True Bell Lamp Shade - Black - 6.5 x 12 x 10.5
# 53.78
# 36.99
# 51.267865375749196
# The Kids Room By Stupell Dinosaurs Typography Chart Oversized Stretched Canvas Wall Art
# Mainstays Motion Sensor Trash Can, 13.2 Gallon, Stainless Steel
# 53.78
# 47.36
# 54.406130268199234
# SCHLEICH Farm World Playmat
# Educational Insights The Sneaky, Snacky Squirrel Game
# 29.99
# 20.34
# 50.98039215686274
# SCHLEICH Farm World Playmat
# Baby Activity Gym Game Center Turtle Play Mat Infant Hanging Toys Toddler Balls Pit Grow Development Station
# 29.99
# 58.95
# 50.98039215686274
# SCHLEICH Farm World Playmat
# Dexbaby Big Mouth Leak-Proof Dura Bib w/ Catch-All Pocket - Large | 6 months + (4 Pack)
# 29.99
# 27.99
# 80.68181818181819
# The Kids Room by Stupell Hold Him A Little Longer Teal Stretched Canvas Wall Art
# The Kids Room by Stupell This is My Happy Place Copper Typography Oversized Stretched Canvas Wall Art, 24 x 1.5 x 30
# 35.99
# 50.26
# 80.0
# The Kids Room by Stupell Hold Him A Little Longer Teal Stretched Canvas Wall Art
# The Kids Room by Stupell Elephant Family Pink Balloon Linen Look Stretched Canvas Wall Art
# 35.99
# 31.49

# %%
for idx, match_index, score in matching_product_list:
    print(df2_cleaned["Product Name"][match_index])
# Out:
# Kenneth Cole Reaction Eau De Parfum Spray For Women 3.40 Oz
# LIFEWTR, Premium Purified Water, pH Balanced with Electrolytes For Taste, 500 ml bottles (Pack of 12) (Packaging May Vary)
# MABIS Vida Mia Digital 20-Second Flexible Tip Childs Duck Thermometer
# (Price/CS)Mrs. Millers Spicy Chili Bacon Jam 12/9oz, 571496
# Foldable Teepee Tent Kids Classic Play Castle Land Kids Tabernacle Indoor Playhouse Camping Playground Special Offer
# Ruffies Pro 42 Gallon Wing Tie 20 count
# (Price/CS)Mrs. Millers Spicy Chili Bacon Jam 12/9oz, 571496
# Ruffies Pro 42 Gallon Wing Tie 20 count
# Ruffies Pro 42 Gallon Wing Tie 20 count
# Ruffies Pro 42 Gallon Wing Tie 20 count
# Ruffies Pro 42 Gallon Wing Tie 20 count
# (Price/CS)Mrs. Millers Spicy Chili Bacon Jam 12/9oz, 571496
# Ruffies Pro 42 Gallon Wing Tie 20 count
# Ruffies Pro 42 Gallon Wing Tie 20 count
# Ruffies Pro 42 Gallon Wing Tie 20 count

# %%
len(matching_product_list)
# Out:
# 15

# %%
df1_cleaned['Category']
# Out:
# 0        Sports & Outdoors | Outdoor Recreation | Skate...
# 1        Toys & Games | Learning & Education | Science ...
# 2                Toys & Games | Arts & Crafts | Craft Kits
# 3        Toys & Games | Hobbies | Models & Model Kits |...
# 4                  Toys & Games | Puzzles | Jigsaw Puzzles
#                                ...
# 9997     Toys & Games | Learning & Education | Counting...
# 9998                          Toys & Games | Arts & Crafts
# 9999     Office Products | Office & School Supplies | E...
# 10000            Toys & Games | Arts & Crafts | Craft Kits
# 10001    Home & Kitchen | Furniture | Kids' Furniture |...
# Name: Category, Length: 10002, dtype: object

# %%
df2_strings = df2_cleaned['concat'].tolist()

# Match rows in df1 to the best row in df2
matches = []
for idx, row in df1_cleaned['concat'].items():
    # Get the best match and score using rapidfuzz's extractOne
    match, score, match_index = process.extractOne(row, df2_strings, scorer=fuzz.token_sort_ratio)
    matches.append((idx, match_index, score))
    print(f"Match: {df1_cleaned["Product Name"][idx]} -> {df2_cleaned['Product Name'][match_index]}")
    print(score)
# Out:
# Match: DB Longboards CoreFlex Crossbow 41" Bamboo Fiberglass Longboard Complete -> Moose Complete Skateboard STAINED BLUE 7.5" Silver/White ASSEMBLED
# 51.131401349741964
# Match: Electronic Snap Circuits Mini Kits Classpack, FM Radio, Motion Detector, Music Box (Set of 5) -> Just Born Little Dreamer Musical Crib Mobile, Grey Elephant, Zebra, Giraffe
# 47.9328165374677
# Match: 3Doodler Create Flexy 3D Printing Filament Refill Bundle (X5 Pack, Over 1000'. of Extruded Plastics! - Innovate -> Duralite 13 x 13 ft. Safari Party House
# 48.95522388059701
# Match: Guillow Airplane Design Studio with Travel Case Building Kit -> Big Brim Safari Hat-Size:X-Large
# 47.127784290738575
# Match: Woodstock- Collage 500 pc Puzzle -> Listerine Original 500 mL (Pack of 6)
# 44.688644688644686
# Match: Terra by Battat – 4 Dinosaur Toys, Medium – Dinosaurs for Kids & Collectors, Scientifically Accurate & Designed by A Paleo-Artist; Age 3+ (4 Pc) -> 360GT Searchbait Lure
# 46.6755912539045
# Match: Rubie's Child's Pokemon Deluxe Pikachu Costume, X-Small -> Eye Mask (Pack Of 24)
# 48.541278708876476
# Match: Hoffmaster 120813 Double-Tipped Triangular Crayon, 88 mm Length, Wrapped (500 Packs of 2) -> Dettol Original Soap, 125g (Pack of 4)
# 37.241379310344826
# Match: ARTSCAPE Etched Glass 24" x 36" Window Film, 24-by-36-Inch -> WPM 4 Piece Blackout Curtain Set. Grommet Curtains and Tie Backs (Navy)
# 46.06345475910694
# Match: Pokemon TCG: Sun and Moon Crimson Invasion Elite Trainer Box -> Pokemon Sun & Moon Ultra Prism Trading Cards 5 Pack Blister Bundle
# 47.93152639087018
# Match: Moonlite, 3-Story Bundle for Boys, Includes 3 Story Reels for Use with Storybook Projector -> Verus SportsExpert Kubb Game
# 52.29389444636081
# Match: DC Cover Girls: Black Canary by Joëlle Jones Statue -> Roller Derby Elite U772BT-08 Sabina Candi Girl Womens Roller Skate, Black & Teal - Size 8
# 46.04715672676838
# Match: Baby Doll Bedding Chevron Window Valance and Curtain Set, Orange -> aBaby Toddler Mattress Protector and Sheet Combo, White
# 49.46236559139785
# Match: LEGO Minecraft Creeper BigFig and Ocelot Characters 21156 Buildable Toy Minecraft Figure Gift Set for Play and Decoration, New 2020 (184 Pieces) -> Beach Toys Bucket And Shovel Set - 8 Piece In Zipper Bag With Handle Clear Re-Usable Bag Fun Play Set For Kids Castle And Animal Molds Easy Store
# 50.61019382627423
# Match: C&D Visionary DC Comic Originals Flash Logo Sticker -> Regal Games Easy Read High Contrast Bingo Calling Card Deck
# 48.747152619589976
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23724\3585561670.py in ?()
#       5 for idx, row in df1_cleaned['concat'].items():
#       6     # Get the best match and score using rapidfuzz's extractOne
#       7     match, score, match_index = process.extractOne(row, df2_strings, scorer=fuzz.token_sort_ratio)
#       8     matches.append((idx, match_index, score))
# ----> 9     print(f"Match: {df1_cleaned["Product Name"][idx]} -> {df2_cleaned['Product Name'][match_index]}")
#      10     print(score)
#
# d:\Miniconda3\envs\dm\Lib\site-packages\pandas\core\frame.py in ?(self, key)
# -> 4062     def __getitem__(self, key):
#    4063         check_dict_or_set_indexers(key)
#    4064         key = lib.item_from_zerodim(key)
#    4065         key = com.apply_if_callable(key, self)
#
# KeyboardInterrupt:

# %%
def fuzzy_match_products(df1, df2):
    matches = []
    for idx, name in df1[column].items():
        # Find the best match in df2
        
        match = process.extractOne(name, df2[column], scorer=fuzz.partial_ratio)
        print(name)
        print(match)
    return pd.DataFrame(matches)

# %%
fuzzy_matches = fuzzy_match_products(df1, df2)
fuzzy_matches
# Out:
# DB Longboards CoreFlex Crossbow 41" Bamboo Fiberglass Longboard Complete
# ('AMBI', 75, 4288)
# Electronic Snap Circuits Mini Kits Classpack, FM Radio, Motion Detector, Music Box (Set of 5)
# ('Fruit', 80, 191)
# 3Doodler Create Flexy 3D Printing Filament Refill Bundle (X5 Pack, Over 1000'. of Extruded Plastics! - Innovate
# ('0', 100, 25663)
# Guillow Airplane Design Studio with Travel Case Building Kit
# ('Salad Dressing', 64, 25173)
# Woodstock- Collage 500 pc Puzzle
# ('0', 100, 25663)
# Terra by Battat – 4 Dinosaur Toys, Medium – Dinosaurs for Kids & Collectors, Scientifically Accurate & Designed by A Paleo-Artist; Age 3+ (4 Pc)
# ('Medium', 100, 28309)
# Rubie's Child's Pokemon Deluxe Pikachu Costume, X-Small
# ('Small', 100, 12989)
# Hoffmaster 120813 Double-Tipped Triangular Crayon, 88 mm Length, Wrapped (500 Packs of 2)
# ('0', 100, 25663)
# ARTSCAPE Etched Glass 24" x 36" Window Film, 24-by-36-Inch
# ('Teeth', 60, 9997)
# Pokemon TCG: Sun and Moon Crimson Invasion Elite Trainer Box
# ('Enter Sandbox', 70, 760)
# Moonlite, 3-Story Bundle for Boys, Includes 3 Story Reels for Use with Storybook Projector
# ('S.O.S', 80, 27836)
# DC Cover Girls: Black Canary by Joëlle Jones Statue
# ('Eye Black', 67, 10791)
# Baby Doll Bedding Chevron Window Valance and Curtain Set, Orange
# ('Ab Solo', 71, 4165)
# LEGO Minecraft Creeper BigFig and Ocelot Characters 21156 Buildable Toy Minecraft Figure Gift Set for Play and Decoration, New 2020 (184 Pieces)
# ('0', 100, 25663)
# C&D Visionary DC Comic Originals Flash Logo Sticker
# ('OLD SPICE', 67, 5116)
# The Learning Journey ABC Melody Maker, Primary
# ('Ab Wheel', 62, 20630)
# The Complete Common Core: State Standards Kit, Grade 5
# ('Teal Sand', 78, 17441)
# Flash Furniture 25''W x 45''L Trapezoid Red HP Laminate Activity Table - Height Adjustable Short Legs
# ('AMBI', 75, 4288)
# Schylling Veterinarian Kit
# ('1152021 Schylling Mermaid Bath Stories Bath Toy', 65, 7870)
# Yellies! Frizz; Voice-Activated Spider Pet; Ages 5 & Up
# ('OLD SPICE', 67, 5116)
# Disney HK318329 Sofia The First Sleepover Set
# ('THE FIRST YEARS', 73, 3)
# Team Associated 9665 Hinge Pin Brace with Hinge Pins B4/T4
# ('Pink', 75, 28355)
# PLUS PLUS - Construction Building Toy, Open Play Set - 3,600 Pieces with Storage Tub - Basic Color Mix
# ('0', 100, 25663)
# Big Party Pack Orange Peel Plastic Plates | 10.25" | Pack of 50 | Party Supply
# ('0', 100, 25663)
# Peppa Pig Shape Sorter Clock Puzzle (12Piece)
# ('Pineapple', 62, 27846)
# Huffy Kids Bikes 16 & 20 inch with Streamers and BMX Pegs
# ('0', 100, 25663)
# NKOK Sonic and Sega All Stars Racing Remote Controlled Car - Sonic The Hedgehog
# ('ALLSTAR CHIN STRAP', 72, 11044)
# Industro Stainless Steel Hose Clamps
# ('Endust Stainless Steel Cleaner, 12.5 oz', 79, 6522)
# Oopsy Daisy Birchwood Owl Growth Chart, Pink, 12" x 42"
# ('Pink', 100, 28355)
# Springbok Puzzles - Christmas Wishes - 400 Piece Jigsaw Puzzle - Large 26.75 Inches by 20.5 Inches Puzzle - Made in USA - Unique Cut Interlocking Pieces - Big Pieces for Kids & Small Pieces for Adults
# ('Small', 100, 12989)
# Franklin Sports Eye Black Stickers for Kids - Customizable Lettering Baseball and Football Eye Black Stickers - White Pencil Included
# ('Eye Black', 100, 10791)
# Costume Sunglasses Clown from IT Sun-Staches Party Favors UV400
# ('0', 100, 25663)
# Jay Franco Disney Frozen 2 Forest Spirit Twin/Full Comforter & Sham Set, Mutli
# ('Disney Frozen 2 Storage Bench', 69, 8171)
# TAMASHII NATIONS Bandai S.H. Figuarts Captain America & Tamashii Effect Explosion Avengers: Infinity War Action Figure
# ('BON AMI', 71, 7587)
# Forum Novelties Union Officer Child's Costume, Medium
# ('Medium', 100, 28309)
# Weiler 14506 Nylox Cup Brush, 6", 0.40/80SC Crimped Fill, 5/8"-11 UNC Nut
# ('0', 100, 25663)
# Disney Mickey Golf Ball Spinner Pewter Key Ring Key Accessory
# ('Pink', 75, 28355)
# Anagram International 3085101 Go Team Megaphone Shop Balloon Pack, 29"
# ('0', 100, 25663)
# Happy Birthday Jointed Letter Banner, Under Construction
# ('Happy Birthday Jelly Belly Beans', 70, 26135)
# Poopsie Unicorn Crush with Glitter and Slime Surprise (2-Pack)
# ('Teal Sand', 67, 17441)
# Funko Pop! Games: Persona 5 - The Joker (Styles May Vary)
# ('Banzai Skimboard Surfer (STYLES MAY VARY)', 67, 11622)
# Klutz Decorate This Journal Toy
# ('Teeth', 80, 9997)
# Random Esoteric Creature Generator for Classic Fantasy Rpgs & Their Modern Simulacra
# ('FARNAM', 67, 16299)
# Bachmann Trains Great Northern Gondola
# ('Gelatin', 71, 8850)
# Disney's Alice in Wonderland, "The Hatter's Mad" Woven Tapestry Throw Blanket, 48" x 60", Multi Color
# ('0', 100, 25663)
# Pacific Play Tent Agility Dog Training Chute
# ('Pacifier (CD)', 74, 23853)
# Barbie Babysitters Inc. Popcorn Set
# ('Popcorn', 100, 28639)
# Losi Ride Height Gauge, LOSA99173
# ('SOLO', 67, 5389)
# Melissa & Doug Disney Cinderella Rags to Riches Wooden Magnetic Game With 10 Magnetic Pieces and Wand
# ('0', 100, 25663)
# VTech Twist and Hug Koala Rattle
# ('Letter Z Football Orange, White and Regalia Retractable Badge Reel CJ1072-ZBR', 62, 16609)
# LAMO 5" Vinyl Figure - Legacy Gamers Dr Disrespect, Red
# ('Pet Treat', 67, 6579)
# Marvel Avengers Assemble Captain America Costume T-Shirt with Mask, Small
# ('Small', 100, 12989)
# Vallejo Game Color Sunblast Yellow Paint, 17ml
# ('SOLO', 75, 5389)
# Mudpuppy Unicorn Magic Activity Coloring Roll, Age 4+, Creative Fun with Coloring, Mazes, Spot The Difference and More, Includes 5 Colored Pencils, Easy to Store Unicorn Paper Roll
# ('S.O.S', 80, 27836)
# Top Trumps Liverpool FC 18/19 Card Game
# ('AMEDA', 75, 13920)
# Hot Wheels Track Builder Straight Track with Car AND Hot Wheels Race Case Track Set
# ('OneWheel+', 75, 2598)
# Wild Republic Mermaid Toy, Slap Bracelet, Gifts for Kids, Purple, Huggers 12"
# ('Teeth', 60, 9997)
# Melissa & Doug Annie Doll & Feeding Set Bundle
# ('CAMELION', 67, 25491)
# LeapFrog LeapStart Preschool 4-in-1 Activity Book Bundle with ABC, Shapes & Colors, Math, Animals
# ('SOLO', 75, 5389)
# Sherlock Holmes - The Challenge of Irene Adler
# ('RENEW LIFE', 70, 7656)
# Great Eastern Entertainment Boys Attack On Titan - Levi Wallet
# ('Pet Treat', 67, 6579)
# Domez My Hero Academia 4-Piece Bundle
# ('Epic Skates Epic Pink Galaxy Elite Quad Roller Skate 3-piece Bundle', 64, 12457)
# Paw Patrol, Mighty Pups Charged Up Chase’s Deluxe Vehicle with Lights and Sounds
# ('Snake and Sword', 67, 1157)
# Alex Discover Button Art Activity Set Kids Art and Craft Activity
# ('Fruit', 60, 191)
# DC Collectibles DCTV: Black Lightning Resin Statue
# ('Rosin Bag', 67, 1865)
# Rubie's Adult 2-Tone Costume Wig
# ('Fruit', 67, 191)
# Funko Pop! Rides: Mulan - Mulan On Khan
# ('S.O.S', 60, 27836)
# Flaghouse Chrome Bowling Ball Ramp
# ('Hammer Bowling Ball Cup', 79, 4026)
# Trends International DC Comics Movie-Batman v Superman Wall Poster, 14.725" x 22.375", Premium Unframed
# ('AMEDA', 89, 13920)
# Aurora World Sweet and Softer Perky Penguin 9.5" Plush
# ('OLD SPICE', 67, 5116)
# Baby Alive Luv 'n Snuggle Baby Doll Blond
# ('Ab Solo', 71, 4165)
# Mega Construx Welliewishers Playful Playhouse Buildable Playset
# ('AMEDA', 67, 13920)
# Aurora World Miyoni Poodle Pup Plush
# ('Aurora World Inc. Paddle Pals9" Paddle Bunny Light Pink', 74, 409)
# Squish-Dee-Lish Squishy Jumbo Toy, Squishies - Slow Rising Pup-Corn, Soft Kids Squishy Toys 86715
# ('S.O.S', 80, 27836)
# Mon AMI Pink Piglet Ballerina Designer Plush Doll, Exquisite Craftmanship, Premium Quality, Cuddling, Collecting & Playing Toy, Baby or Toddler Gift 18", Multicolor
# ('Pink', 100, 28355)
# Proline 1013214 Hyrax 2G8 Rock Terrain Truck Tires (2)
# ('0', 100, 25663)
# RoomMates Curious George Peel and Stick Giant Wall Decal - RMK1082GM
# ('0', 100, 25663)
# NECA - Teenage Mutant Ninja Turtles (1990 Movie) Prop Replica
# ('0', 100, 25663)
# Hansa Ostrich Baby Plush
# ('S.O.S', 80, 27836)
# RPM 73162 Axle Carriers Black 1/16 Traxxas Black
# ('Eye Black', 80, 10791)
# Mikasa VSO2000 FIVB Replica Volleyball
# ('0', 100, 25663)
# The Corps Special Forces Action Figures & Vehicle Deluxe Playset (Packaging & Colors May Vary)
# ('SOLO', 75, 5389)
# Creativity for Kids Clay Keychains
# ('Mgaxyff Pop Up Soccer Goal,Pop Up Soccer Goal Set Portable Football Training Sports Toy for Kids Early Educational Toy , Portable Mini Soccer Goal', 65, 22836)
# Herbaceous
# ('Herbacin Cosmetics Kamille Paraben-Free Hand Cream 2.5 oz', 75, 897)
# Wild Republic Snake Plush, Snake Stuffed Animal, Plush Toy, Pet Snake, Sherbert, 54"
# ('S.O.S', 80, 27836)
# NPW-USA NPW67309 Drinking Buddies Dice Game, 6-Piece Set
# ('0', 100, 25663)
# Blade 130 S BNF Basic With Safe
# ('0', 100, 25663)
# Madame Alexander 8" ICY Elegance Light Skin Tone Blue Eyes/Blonde Hair
# ('AMEDA', 80, 13920)
# NCAA Georgia Bulldogs Toy Puzzle Cube
# ('Table Top Toss Gray 1 NCAA Georgia Bulldogs', 72, 9331)
# COBI Historical Collection M3 Grant Tank
# ('Pink', 67, 28355)
# Learning Resources Serve It Up! Play Restaurant, Pretend Restaurant Set, 35 Pieces, Ages 3+
# ('Flexware', 67, 7265)
# Amscan 120175 Banner, 8' x 6 1/2", Multi Color
# ('0', 100, 25663)
# Melissa & Doug K’s Kids Whose Tail? 8-Page Soft Activity Book, The Original (Great Gift for Girls and Boys - Best for Babies and Toddlers, All Ages)
# ('AMBI', 75, 4288)
# Bachmann Old-Time Box Car - Pennsylvania LINES - N Scale, Prototypical Oxide Red
# ('Silva', 80, 24244)
# Jumbo Foil Star Cutout (gold) Party Accessory (1 count)
# ('Oil Seal', 75, 2469)
# Aquarius I Heart Unicorns Playing Cards
# ('Missouri Souvenir Playing Cards', 71, 27812)
# Great Eastern Mega Man X4 9" Plush
# ('Pet Treat', 67, 6579)
# Robinson Racing Products Robinson Racing 1710 Hardened 10T Pinion Gear 32P, Brown/A
# ('0', 100, 25663)
# Maisto R/C 1:14 Scale Lamborghini Huracan Radio Control Vehicle (Colors May Vary)
# ('AMBI', 75, 4288)
# Aquarius DC Wonder Woman Retro Playing Cards
# ('TOY PLAYING CARDS GOT 2ND ED.', 71, 15899)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fuzzy_matches = fuzzy_match_products(df1, df2)
#       2 fuzzy_matches
#
# Cell In[27], line 6, in fuzzy_match_products(df1, df2, column, threshold)
#       2 matches = []
#       3 for idx, name in df1[column].items():
#       4     # Find the best match in df2
# ----> 6     match = process.extractOne(name, df2[column], scorer=fuzz.partial_ratio)
#       7     print(name)
#       8     print(match)
#
# File d:\Miniconda3\envs\dm\Lib\site-packages\thefuzz\process.py:261, in extractOne(query, choices, processor, scorer, score_cutoff)
#     258 is_lowered = scorer in _scorer_lowering
#     260 query = _preprocess_query(query, processor)
# --> 261 res = rprocess.extractOne(
#     262     query, choices,
#     263     processor=_get_processor(processor, scorer),
#     264     scorer=_get_scorer(scorer),
#     265     score_cutoff=score_cutoff
#     266 )
#     268 if res is None:
#     269     return res
#
# File src/rapidfuzz/process_cpp_impl.pyx:680, in rapidfuzz.process_cpp_impl.extractOne()
#
# File src/rapidfuzz/process_cpp_impl.pyx:399, in rapidfuzz.process_cpp_impl.extractOne_dict()
#
# File src/rapidfuzz/process_cpp_impl.pyx:292, in rapidfuzz.process_cpp_impl.extractOne_dict_f64()
#
# File d:\Miniconda3\envs\dm\Lib\site-packages\thefuzz\utils.py:22, in full_process(s, force_ascii)
#      19 if force_ascii:
#      20     s = ascii_only(str(s))
# ---> 22 return _default_process(s)
#
# KeyboardInterrupt:
